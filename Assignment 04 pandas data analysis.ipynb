# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#1count how many number of posts are paid and unpaid?
# load the data using pandas
df = pd.read_csv('datasets/fb.csv')
print('fb dataset\n',df)
# Out:
# fb dataset
#       Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# label based slicing
paid= df[df['Paid']==1]

# %%
row, col=paid.shape
paidrows = row

# %%
unpaid= df[df['Paid']==0]

# %%
row, col=unpaid.shape
unpaidrows = row

# %%
total = paidrows+unpaidrows
print('Total paid and unpaid posts are: \n',total)
# Out:
# Total paid and unpaid posts are:
#  499

# %%
cric_list = df.loc[:, ['Page total likes', 'Type','Post Month', 'like','comment', 'share',]]

# %%
print('Given columns:\n', cric_list)
# Out:
# Given columns:
#       Page total likes    Type  Post Month    like  comment  share
# 0              139441   Photo          12    79.0        4   17.0
# 1              139441  Status          12   130.0        5   29.0
# 2              139441   Photo          12    66.0        0   14.0
# 3              139441   Photo          12  1572.0       58  147.0
# 4              139441   Photo          12   325.0       19   49.0
# ..                ...     ...         ...     ...      ...    ...
# 495             85093   Photo           1    53.0        5   26.0
# 496             81370   Photo           1    53.0        0   22.0
# 497             81370   Photo           1    93.0        4   18.0
# 498             81370   Photo           1    91.0        7   38.0
# 499             81370   Photo           1    91.0        0   28.0
#
# [500 rows x 6 columns]

# %%
info_fifth_m = df['Post Month']
sep_month = df[info_fifth_m==9]
print('Selecting DataSet \n', sep_month)
# Out:
# Selecting DataSet
#       Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 155            135700   Photo         2           9             3          7
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
# 161            135617   Photo         2           9             7          3
# 162            135617   Photo         3           9             6         10
# 163            135617  Status         2           9             6          4
# 164            135428   Photo         1           9             5         10
# 165            135428   Photo         2           9             5          3
# ...

# %%
sep_list = sep_month.loc[:, ['Post Month', 'Post Weekday','Post Weekday']]
sep_list.mean()
# Out:
# Post Month      9.000000
# Post Weekday    3.666667
# Post Weekday    3.666667
# dtype: float64
