# %%
# Name: E Naresh

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#####1 Load the data set
df = pd.read_csv('datasets/grapes_new.csv')
print('Quality of grapes data by ICAR\n',df)
# Out:
# Quality of grapes data by ICAR
#       COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
# ...

# %%
##### 3 Cleaning the data set

# %%
df = df.drop(['SHAPE','SOIL_TYPE'], axis = 1) #removed the soil type and shape columns

# %%
df.columns
# Out:
# Index(['COLOR_INTENSITY', 'RIPENESS_PER', 'ALCOHOL_PER', 'MALIC_ACID_PER',
#        'ASH', 'ALCALINITY_OF_ASH', 'MAGNESIUM_MEASURE', 'TOTAL_PHENOLS',
#        'FLAVANOIDS', 'PROANTHOCYANINS', 'HUE', 'PROLINE', 'TEMPERATURE',
#        'AVG_HUMIDITY', 'FERT_NITRO_PER', 'WATER_O2_PER', 'WATER_PH',
#        'FER_P2O5_PER', 'CLASS'],
#       dtype='object')

# %%
df.count()
# Out:
# COLOR_INTENSITY      194
# RIPENESS_PER         192
# ALCOHOL_PER          191
# MALIC_ACID_PER       194
# ASH                  194
# ALCALINITY_OF_ASH    188
# MAGNESIUM_MEASURE    194
# TOTAL_PHENOLS        194
# FLAVANOIDS           194
# PROANTHOCYANINS      194
# HUE                  192
# PROLINE              194
# TEMPERATURE          194
# AVG_HUMIDITY         194
# FERT_NITRO_PER       194
# WATER_O2_PER         190
# WATER_PH             194
# FER_P2O5_PER         194
# CLASS                194
# dtype: int64

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# CLASS                0
# dtype: int64

# %%
df.duplicated() #to check the status of the duplicated data
# it is found that there no duplication of data
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# Length: 194, dtype: bool

# %%
df = df.ffill() #copying data from forward values

# %%
df.isnull().sum()
# Out:
# COLOR_INTENSITY      0
# RIPENESS_PER         0
# ALCOHOL_PER          0
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    0
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  0
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         0
# WATER_PH             0
# FER_P2O5_PER         0
# CLASS                0
# dtype: int64

# %%
#2 separate the input and output variable
x = df.drop('CLASS', axis = 1) #input variable
y = df['CLASS']#output variable

# %%
df.count()
# Out:
# COLOR_INTENSITY      194
# RIPENESS_PER         194
# ALCOHOL_PER          194
# MALIC_ACID_PER       194
# ASH                  194
# ALCALINITY_OF_ASH    194
# MAGNESIUM_MEASURE    194
# TOTAL_PHENOLS        194
# FLAVANOIDS           194
# PROANTHOCYANINS      194
# HUE                  194
# PROLINE              194
# TEMPERATURE          194
# AVG_HUMIDITY         194
# FERT_NITRO_PER       194
# WATER_O2_PER         194
# WATER_PH             194
# FER_P2O5_PER         194
# CLASS                194
# dtype: int64

# %%
#4 Explore the output variable through countplot, pie chart
y.value_counts()
# Out:
# CLASS
# Medium    76
# High      64
# Low       54
# Name: count, dtype: int64

# %%
#count plot
plt.figure(figsize=(16,9))
sns.countplot(y=y)
# Out:
# <Axes: xlabel='count', ylabel='CLASS'>

# %%
# pie chart
plt.pie(y.value_counts(), labels = y.value_counts().index, autopct='%2.2f%%');

# %%
#6 Explore kde plot 
sns.kdeplot(df['ALCOHOL_PER'], label="alcoholper", color="blue")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='ALCOHOL_PER', ylabel='Density'>

# %%
sns.kdeplot(df['TEMPERATURE'], label="Temperature", color="green")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TEMPERATURE', ylabel='Density'>

# %%
sns.kdeplot(df['AVG_HUMIDITY'], label="Humidity", color="red")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='AVG_HUMIDITY', ylabel='Density'>

# %%
sns.kdeplot(df['FERT_NITRO_PER'], label="Nitrogen Fertilizer", color="green")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='FERT_NITRO_PER', ylabel='Density'>

# %%
sns.kdeplot(df['WATER_PH'], label="Water PH", color="blue")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='WATER_PH', ylabel='Density'>

# %%
#7 apply encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['CLASS'] = le.fit_transform(df['CLASS'])
df
# Out:
#      COLOR_INTENSITY  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER   ASH  \
# 0             120.53         16.73        14.23            1.71  2.43
# 1             112.57         20.30        13.20            1.78  2.14
# 2             120.78         20.81        13.16            2.36  2.67
# 3             134.17         19.47        14.37            1.95  2.50
# 4             112.19         17.57        13.24            2.59  2.87
# ..               ...           ...          ...             ...   ...
# 189           102.34         21.23        12.07            2.16  2.17
# 190           109.80         21.67        12.43            1.53  2.29
# 191           103.86         22.01        11.79            2.13  2.78
# 192            98.30         21.95        12.37            1.63  2.30
# 193           101.33         21.60        12.04            4.30  2.38
#
#      ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# ...

# %%
#8 implement feature selection method
from sklearn.feature_selection import SelectKBest, chi2 #select important most imp features for devolopment of ml model
skf = SelectKBest(k = 5, score_func =chi2)
skf.fit(x, df['CLASS'])
# Out:
# SelectKBest(k=5, score_func=<function chi2 at 0x0000020F211B0540>)

# %%
skf.fit(x,y)
# Out:
# SelectKBest(k=5, score_func=<function chi2 at 0x0000020F211B0540>)

# %%
skf.get_support()
# Out:
# array([ True, False, False, False, False, False, False, False,  True,
#        False, False,  True,  True, False, False, False, False,  True])

# %%
x.iloc[:,skf.get_support()]
# Out:
#      COLOR_INTENSITY  FLAVANOIDS  PROLINE  TEMPERATURE  FER_P2O5_PER
# 0             120.53        3.06     1065        23.34         52.02
# 1             112.57        2.76     1050        23.40         48.18
# 2             120.78        3.24     1185        22.29         28.15
# 3             134.17        3.49     1480        21.28         55.95
# 4             112.19        2.69      735        23.76         55.99
# ..               ...         ...      ...          ...           ...
# 189           102.34        2.65      378        25.58         55.83
# 190           109.80        3.15      352        24.23         55.47
# 191           103.86        2.24      466        27.62         47.57
# 192            98.30        2.45      342        27.54         45.91
# 193           101.33        1.75      580        25.10         52.42
#
# [194 rows x 5 columns]

# %%
# 9feature scalling technique
#import the class and minmmax scalar
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
#apply scaling
x_scaled = scalar.fit_transform(x)
x_scaled
# Out:
# array([[0.37202703, 0.0620155 , 0.84210526, ..., 0.89180835, 0.60301508,
#         0.78345975],
#        [0.26445946, 0.45736434, 0.57105263, ..., 0.96290572, 0.57788945,
#         0.6895033 ],
#        [0.37540541, 0.51384275, 0.56052632, ..., 0.9062339 , 0.57788945,
#         0.19941277],
#        ...,
#        [0.14675676, 0.64673311, 0.2       , ..., 0.30654302, 0.53266332,
#         0.67457793],
#        [0.07162162, 0.64008859, 0.35263158, ..., 0.52756311, 0.32160804,
#         0.63396134],
#        [0.11256757, 0.6013289 , 0.26578947, ..., 0.40082432, 0.08542714,
#         0.79324688]])

# %%
#10 cross validation
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.2, stratify=y) #balance of data is maintained using stratify

# %%
x_train.shape, x_test.shape, y_test.shape, y_test.shape
# Out:
# ((155, 18), (39, 18), (39,), (39,))

# %%
# 11 build the model and implementation of classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB


dt_clf = DecisionTreeClassifier(random_state = 0)
rf_clf = RandomForestClassifier(n_estimators=10, random_state = 0)
knn_clf =  KNeighborsClassifier(n_neighbors=5)
sv_clf = SVC(random_state = 0, kernel = 'rbf')
nb_clf = GaussianNB()

#train the algorithnm
dt_clf.fit(x_train, y_train)
rf_clf.fit(x_train, y_train)
knn_clf.fit(x_train, y_train)
sv_clf.fit(x_train, y_train)
nb_clf.fit(x_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GaussianNB()

# %%
#prediction
dt_clf_pred = dt_clf.predict(x_test)
rf_clf_pred = rf_clf.predict(x_test)
knn_clf_pred = knn_clf.predict(x_test)
sv_clf_pred =sv_clf.predict(x_test)
nb_clf_pred = nb_clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('dt_clf_pred:', accuracy_score(y_test, dt_clf_pred))
print('rf_clf_pred:', accuracy_score(y_test, rf_clf_pred))
print('knn_clf_pred:', accuracy_score(y_test, knn_clf_pred))
print('sv_clf_pred:', accuracy_score(y_test, sv_clf_pred))
print('nb_clf_pred:', accuracy_score(y_test, nb_clf_pred))
# Out:
# dt_clf_pred: 0.9743589743589743
# rf_clf_pred: 1.0
# knn_clf_pred: 0.8717948717948718
# sv_clf_pred: 0.5897435897435898
# nb_clf_pred: 0.9230769230769231

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay

# %%
print(confusion_matrix(y_test, dt_clf_pred))
# Out:
# [[12  0  1]
#  [ 0 11  0]
#  [ 0  0 15]]

# %%
#confusion matrix for decision tree classifier
ConfusionMatrixDisplay.from_predictions(y_test,dt_clf_pred)

# %%
print(classification_report(y_test,dt_clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      0.92      0.96        13
#          Low       1.00      1.00      1.00        11
#       Medium       0.94      1.00      0.97        15
#
#     accuracy                           0.97        39
#    macro avg       0.98      0.97      0.98        39
# weighted avg       0.98      0.97      0.97        39

# %%
ConfusionMatrixDisplay.from_predictions(y_test,rf_clf_pred)
print(classification_report(y_test,rf_clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00        13
#          Low       1.00      1.00      1.00        11
#       Medium       1.00      1.00      1.00        15
#
#     accuracy                           1.00        39
#    macro avg       1.00      1.00      1.00        39
# weighted avg       1.00      1.00      1.00        39

# %%
ConfusionMatrixDisplay.from_predictions(y_test,knn_clf_pred)
print(classification_report(y_test,knn_clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.83      0.77      0.80        13
#          Low       0.83      0.91      0.87        11
#       Medium       0.93      0.93      0.93        15
#
#     accuracy                           0.87        39
#    macro avg       0.87      0.87      0.87        39
# weighted avg       0.87      0.87      0.87        39

# %%
ConfusionMatrixDisplay.from_predictions(y_test,sv_clf_pred)
print(classification_report(y_test,sv_clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.82      0.69      0.75        13
#          Low       0.00      0.00      0.00        11
#       Medium       0.50      0.93      0.65        15
#
#     accuracy                           0.59        39
#    macro avg       0.44      0.54      0.47        39
# weighted avg       0.47      0.59      0.50        39
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
ConfusionMatrixDisplay.from_predictions(y_test,nb_clf_pred)
print(classification_report(y_test,nb_clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.92      0.85      0.88        13
#          Low       1.00      1.00      1.00        11
#       Medium       0.88      0.93      0.90        15
#
#     accuracy                           0.92        39
#    macro avg       0.93      0.93      0.93        39
# weighted avg       0.92      0.92      0.92        39
