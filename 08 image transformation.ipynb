# %% [markdown]
# ##### iMAGE transfermation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# image translation 
image = cv2.imread('images/img1.jpg')
height, width = image.shape[:2]
quarter_height, quarter_width = height/4, width/4
T= np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])
image_translation= cv2.warpAffine(image, T, (width, height))

# %%
T
# Out:
# array([[1.00000e+00, 0.00000e+00, 1.15575e+03],
#        [0.00000e+00, 1.00000e+00, 8.65000e+02]], dtype=float32)

# %%
cv2.imshow('original image',image)
cv2.imshow('translated image',image_translation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(image)
plt.figure(figsize = (16,9))

# %%
plt.imshow(image_translation)
plt.figure(figsize = (16,9))

# %%
T= np.float32([[1, 0, 40], [0, 1, 40]])
img_translation = cv2.warpAffine(image, T, (width, height))
