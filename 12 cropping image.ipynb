# %%
#cropping
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=plt.imread('images1/Sachin.jpg')
plt.title('Sachin Image')
plt.imshow(img)

# %%
img.shape
# Out:
# (1075, 850, 3)

# %%
img2= img[100:1000,100:800]
plt.imshow(img2)

# %%
plt.subplot(1,2,1)
plt.imshow(img), 
plt.subplot(1,2,2)
plt.imshow(img2)

# %%
height, width, channels = img.shape

# %%
startRow = int(height*0.15)
startCol = int(height*0.15)
endRow = int(height*0.85)
endCol = int(height*0.85)
CroppedImage = img[startRow:endRow, startCol:endCol]
plt.imshow(CroppedImage)

# %%
plt.subplot(1,2,1)
plt.imshow(img), 
plt.subplot(1,2,2)
plt.imshow(CroppedImage)

# %%
x = np.array([[1,0,1],[1,4,3],[1,8,9]])
y = np.array([[1,0,0],[5,3,9],[2,5,9]])
z1 = np.hstack([x,y]) 
z2 = np.vstack([x,y])

# %%
z1, z2
# Out:
# (array([[1, 0, 1, 1, 0, 0],
#         [1, 4, 3, 5, 3, 9],
#         [1, 8, 9, 2, 5, 9]]),
#  array([[1, 0, 1],
#         [1, 4, 3],
#         [1, 8, 9],
#         [1, 0, 0],
#         [5, 3, 9],
#         [2, 5, 9]]))

# %%
flipped_horizantal = cv2.flip(img,1 ) #0,1,-1 flip(hor,ver,dia)
new_img = np.hstack([img, flipped_horizantal])
plt.imshow(new_img)
