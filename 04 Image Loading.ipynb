# %%
#image processing using computer vision
import cv2

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
img1=cv2.imread('images/img1.jpg')

# %%
cv2.imshow('First Image',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# visualisation of image using matplot library
import matplotlib.pyplot as plt

# %%
img2=plt.imread('images/img1.jpg')
plt.imshow(img2)

# %%
#using scikit-image
from skimage import io

# %%
img_ski=io.imread('images/img1.jpg')
plt.imshow(img_ski)

# %%
#pillow method
from PIL import Image

# %%
img_pil=io.imread('images/img1.jpg')
plt.imshow(img_pil)

# %%
#using tensorflow
import tensorflow as tf
img_tf=tf.io.read_file('images/img1.jpg')
img_tf=tf.image.decode_image(img_tf, channels=3)
plt.imshow(img_tf)

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
img1.shape
# Out:
# (3460, 4623, 3)

# %%
img_tf
# Out:
# <tf.Tensor: shape=(3460, 4623, 3), dtype=uint8, numpy=
# array([[[ 19,  20,  15],
#         [ 18,  19,  14],
#         [ 17,  18,  13],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        [[ 19,  20,  15],
#         [ 18,  19,  14],
#         [ 17,  18,  13],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        [[ 18,  19,  14],
#         [ 18,  19,  14],
#         [ 17,  18,  13],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        ...,
#
#        [[ 95,  96,  90],
#         [ 89,  90,  84],
#         [ 85,  86,  80],
#         ...,
#         [ 66,  89,  83],
#         [ 66,  89,  83],
#         [ 66,  89,  83]],
#
#        [[ 93,  94,  88],
#         [ 88,  89,  83],
#         [ 86,  87,  81],
#         ...,
#         [ 66,  89,  83],
#         [ 66,  89,  83],
#         [ 66,  89,  83]],
#
#        [[ 92,  93,  87],
# ...

# %%
img_pil
# Out:
# array([[[ 20,  20,  18],
#         [ 19,  19,  17],
#         [ 17,  17,  15],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        [[ 20,  20,  18],
#         [ 19,  19,  17],
#         [ 18,  18,  16],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        [[ 19,  19,  17],
#         [ 19,  19,  17],
#         [ 18,  18,  16],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        ...,
#
#        [[ 95,  96,  91],
#         [ 90,  91,  86],
#         [ 86,  87,  82],
#         ...,
#         [ 66,  88,  85],
#         [ 66,  88,  85],
#         [ 66,  88,  85]],
#
#        [[ 94,  95,  90],
#         [ 89,  90,  85],
#         [ 86,  87,  82],
#         ...,
#         [ 66,  88,  85],
#         [ 66,  88,  85],
#         [ 66,  88,  85]],
#
#        [[ 92,  93,  88],
#         [ 88,  89,  84],
#         [ 87,  88,  83],
# ...

# %%
img_pil.size
# Out:
# 47986740

# %%
img_pil.shape
# Out:
# (3460, 4623, 3)

# %%
type(img1),type(img_pil),type(img_tf),type(img_ski),type(img_plt)
# Out:
# (numpy.ndarray,
#  numpy.ndarray,
#  tensorflow.python.framework.ops.EagerTensor,
#  numpy.ndarray,
#  numpy.ndarray)

# %%
#create an image
import numpy as np
img_new=np.zeros([100,100])
plt.imshow(img_new, cmap='grey')

# %%
img_new[50,60]=20
plt.imshow(img_new, cmap='grey')

# %%
img_new[50]=70
plt.imshow(img_new, cmap='grey')

# %%
np.random.randint(12,78)
# Out:
# 56

# %%
for i in range(100):
    for j in range(100):
        img_new[i,j] = np.random.randint(0,255)
#img_new1=np.zeros([100,100])
plt.imshow(img_new, cmap='grey')

# %%
#gray scale image creation
img_gray = cv2.imread('images/img1.jpg',0)
img_gray.shape
# Out:
# (3460, 4623)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
img_plt
# Out:
# array([[[ 20,  20,  18],
#         [ 19,  19,  17],
#         [ 17,  17,  15],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        [[ 20,  20,  18],
#         [ 19,  19,  17],
#         [ 18,  18,  16],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        [[ 19,  19,  17],
#         [ 19,  19,  17],
#         [ 18,  18,  16],
#         ...,
#         [230, 236, 232],
#         [230, 236, 232],
#         [230, 236, 232]],
#
#        ...,
#
#        [[ 95,  96,  91],
#         [ 90,  91,  86],
#         [ 86,  87,  82],
#         ...,
#         [ 66,  88,  85],
#         [ 66,  88,  85],
#         [ 66,  88,  85]],
#
#        [[ 94,  95,  90],
#         [ 89,  90,  85],
#         [ 86,  87,  82],
#         ...,
#         [ 66,  88,  85],
#         [ 66,  88,  85],
#         [ 66,  88,  85]],
#
#        [[ 92,  93,  88],
#         [ 88,  89,  84],
#         [ 87,  88,  83],
# ...

# %%
img_plt.shape
# Out:
# (3460, 4623, 3)

# %%
r = img_plt[:,:,0]
g = img_plt[:,:,1]
b = img_plt[:,:,2]
r.shape, g.shape, b.shape
# Out:
# ((3460, 4623), (3460, 4623), (3460, 4623))

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='gray')
plt.subplot(1,3,2)
plt.imshow(g, cmap='gray')
plt.subplot(1,3,3)
plt.imshow(b, cmap='gray')

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap='Reds')
plt.subplot(1,3,2)
plt.imshow(g, cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b, cmap='Blues')

# %%
new_img=(r+g+b)/3
plt.imshow(new_img,cmap='gray')

# %%
plt.subplot(1,2,1)
plt.title('Image Read using cv2')
plt.imshow(img1)
plt.subplot(1,2,2)
plt.title('Image Read using matplotlib')
plt.imshow(img_plt)

# %%
img1
# Out:
# array([[[ 18,  20,  20],
#         [ 17,  19,  19],
#         [ 15,  17,  17],
#         ...,
#         [232, 236, 230],
#         [232, 236, 230],
#         [232, 236, 230]],
#
#        [[ 18,  20,  20],
#         [ 17,  19,  19],
#         [ 16,  18,  18],
#         ...,
#         [232, 236, 230],
#         [232, 236, 230],
#         [232, 236, 230]],
#
#        [[ 17,  19,  19],
#         [ 17,  19,  19],
#         [ 16,  18,  18],
#         ...,
#         [232, 236, 230],
#         [232, 236, 230],
#         [232, 236, 230]],
#
#        ...,
#
#        [[ 91,  96,  95],
#         [ 86,  91,  90],
#         [ 82,  87,  86],
#         ...,
#         [ 85,  88,  66],
#         [ 85,  88,  66],
#         [ 85,  88,  66]],
#
#        [[ 90,  95,  94],
#         [ 85,  90,  89],
#         [ 82,  87,  86],
#         ...,
#         [ 85,  88,  66],
#         [ 85,  88,  66],
#         [ 85,  88,  66]],
#
#        [[ 88,  93,  92],
#         [ 84,  89,  88],
#         [ 83,  88,  87],
# ...

# %%
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.title('Image Read using cv2')
plt.imshow(img2)
plt.subplot(1,2,2)
plt.title('Image Read using matplotlib')
plt.imshow(img_plt)

# %%
import sys

# %%
sys.getsizeof(img1),sys.getsizeof(img2),sys.getsizeof(img_ski),sys.getsizeof(img_pil)
# Out:
# (47986884, 144, 47986884, 47986884)

# %%
sys.getsizeof(img_ski)
# Out:
# 47986884

# %%
img_plt.shape
# Out:
# (3460, 4623, 3)

# %%
sys.getsizeof(img2)
# Out:
# 144

# %%
id(img1), id(img2), id(img_ski), id(img_pil)
# Out:
# (1675868788688, 1676504481936, 1676029832592, 1676030115536)

# %%
id(img2)
# Out:
# 1676504481936

# %%
help(sys.getsizeof)
# Out:
# Help on built-in function getsizeof in module sys:
#
# getsizeof(...)
#     getsizeof(object [, default]) -> int
#
#     Return the size of object in bytes.

# %%
2**32
# Out:
# 4294967296

# %%
2**32 + 144
# Out:
# 4294967440
