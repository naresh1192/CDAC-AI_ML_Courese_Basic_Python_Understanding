# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('images/img1.jpg')
plt.imshow(img, cmap ='gray')
img.shape
# Out:
# (3460, 4623, 3)

# %%
#selecing a pixel from a image
pix =img[2000,4000]
pix=pix.reshape(1,1,3)
plt.imshow(pix)

# %%
import numpy as np
img_new= cv2.imread('images/img1.jpg')
for i in range(3460):
     for j in  range(4623):
        if i==j:
            img_new[i,j]=0

# %%
plt.figure(figsize=(16,9)) #to set the size of an image
plt.imshow(img_new, cmap ='gray')

# %%
img_new[500:1500, 500:2500]=0
plt.imshow(img_new, cmap ='gray')

# %%
img_new = cv2.imread('images/img1.jpg')
for i in range(0,3460,2):
    for j in range(4623):
      img_new[i]=0
plt.imshow(img_new)
